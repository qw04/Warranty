# %%
import pandas as pd
from collections import Counter

# %%
df = pd.read_csv(r"data\raw data\data_Q1_2016\2016-01-01.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57545 entries, 0 to 57544
# Data columns (total 95 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  57545 non-null  object
#  1   serial_number         57545 non-null  object
#  2   model                 57545 non-null  object
#  3   capacity_bytes        57545 non-null  int64
#  4   failure               57545 non-null  int64
#  5   smart_1_normalized    57545 non-null  int64
#  6   smart_1_raw           57545 non-null  int64
#  7   smart_2_normalized    23810 non-null  float64
#  8   smart_2_raw           23810 non-null  float64
#  9   smart_3_normalized    57545 non-null  int64
#  10  smart_3_raw           57545 non-null  int64
#  11  smart_4_normalized    57545 non-null  int64
#  12  smart_4_raw           57545 non-null  int64
#  13  smart_5_normalized    57545 non-null  int64
#  14  smart_5_raw           57545 non-null  int64
# ...

# %%
df.columns[:20]
# Out:
# Index(['date', 'serial_number', 'model', 'capacity_bytes', 'failure',
#        'smart_1_normalized', 'smart_1_raw', 'smart_2_normalized',
#        'smart_2_raw', 'smart_3_normalized', 'smart_3_raw',
#        'smart_4_normalized', 'smart_4_raw', 'smart_5_normalized',
#        'smart_5_raw', 'smart_7_normalized', 'smart_7_raw',
#        'smart_8_normalized', 'smart_8_raw', 'smart_9_normalized'],
#       dtype='object')

# %%
lst = ["TOSHIBA", "WDC", "ST", "HGST", "Seagate", "CT", ]
set(filter(lambda x : x.startswith("DELL"), df['model'].to_list()))
Counter(df['model'].to_list())
# Out:
# Counter({'ST4000DM000': 29024,
#          'HGST HMS5C4040ALE640': 7085,
#          'Hitachi HDS5C3030ALA630': 4558,
#          'Hitachi HDS722020ALA330': 4488,
#          'HGST HMS5C4040BLE640': 3091,
#          'Hitachi HDS5C4040ALE630': 2639,
#          'ST6000DX000': 1882,
#          'WDC WD30EFRX': 1046,
#          'Hitachi HDS723030ALA640': 1000,
#          'ST500LM012 HN': 513,
#          'WDC WD60EFRX': 458,
#          'WDC WD5000LPVX': 262,
#          'ST31500541AS': 222,
#          'ST4000DX000': 212,
#          'TOSHIBA MD04ABA400V': 145,
#          'WDC WD20EFRX': 132,
#          'WDC WD1600AAJS': 98,
#          'ST320LT007': 68,
#          'HGST HDS5C4040ALE630': 60,
#          'ST3160316AS': 52,
#          'ST9250315AS': 51,
#          'TOSHIBA DT01ACA300': 47,
#          'ST3160318AS': 47,
#          'WDC WD40EFRX': 46,
#          'HGST HUH728080ALE600': 45,
#          'TOSHIBA MD04ABA500V': 45,
#          'HGST HDS724040ALE640': 40,
#          'ST250LM004 HN': 32,
# ...
